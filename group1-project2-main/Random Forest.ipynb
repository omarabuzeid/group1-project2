# %%
import pandas as pd
import numpy as np
from pathlib import Path
from joblib import dump, load
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

# %matplotlib inline


import warnings
warnings.filterwarnings('ignore')

import pydotplus
from IPython.display import Image

# %%
elon_csv_path = Path('../group1-project2-main/elon_df.csv')
elon_signals_df = pd.read_csv(elon_csv_path)
tsla_csv_path = Path('../group1-project2-main/TSLA_prices_df.csv')
tsla_results_df = pd.read_csv(tsla_csv_path)
total_data_path = Path('../group1-project2-main/total_data.csv')
total_data = pd.read_csv(total_data_path)

# %%
total_data.head()
# Out:
#                       Unnamed: 0        date   TSLA  earnings flag  \
# 0  1970-01-01 00:00:00.000000361  2011-12-01 -0.028            0.0
# 1  1970-01-01 00:00:00.000000362  2011-12-01 -0.028            0.0
# 2  1970-01-01 00:00:00.000000376  2011-12-21 -0.066            0.0
# 3  1970-01-01 00:00:00.000000377  2011-12-21 -0.066            0.0
# 4  1970-01-01 00:00:00.000000378  2011-12-21 -0.066            0.0
#
#    tweet_length  encoded_sentiment sentiment  polairty  \
# 0         118.0                0.0   neutral     0.000
# 1         141.0                1.0  positive     0.650
# 2          62.0                1.0  positive     0.250
# 3         140.0               -1.0  negative    -0.025
# 4         136.0               -1.0  negative    -0.500
#
#                                                tweet
# 0  I made the volume on the Model S  http://t.co/...
# 1  Went to Iceland on Sat to ride bumper cars on ...
# 2  Yum! Even better than deep fried butter:  http...
# 3  Yeah, this really is me, as my Mom will attest...
# 4  Got called randomly by Kanye West today and re...

# %%
total_data = total_data.set_index('date')
total_data.head()
# Out:
#                                Unnamed: 0   TSLA  earnings flag  tweet_length  \
# date
# 2011-12-01  1970-01-01 00:00:00.000000361 -0.028            0.0         118.0
# 2011-12-01  1970-01-01 00:00:00.000000362 -0.028            0.0         141.0
# 2011-12-21  1970-01-01 00:00:00.000000376 -0.066            0.0          62.0
# 2011-12-21  1970-01-01 00:00:00.000000377 -0.066            0.0         140.0
# 2011-12-21  1970-01-01 00:00:00.000000378 -0.066            0.0         136.0
#
#             encoded_sentiment sentiment  polairty  \
# date
# 2011-12-01                0.0   neutral     0.000
# 2011-12-01                1.0  positive     0.650
# 2011-12-21                1.0  positive     0.250
# 2011-12-21               -1.0  negative    -0.025
# 2011-12-21               -1.0  negative    -0.500
#
#                                                         tweet
# date
# 2011-12-01  I made the volume on the Model S  http://t.co/...
# 2011-12-01  Went to Iceland on Sat to ride bumper cars on ...
# 2011-12-21  Yum! Even better than deep fried butter:  http...
# 2011-12-21  Yeah, this really is me, as my Mom will attest...
# 2011-12-21  Got called randomly by Kanye West today and re...

# %%
total_data = total_data.drop(columns = ['Unnamed: 0'])

# %%
total_data.tail()
# Out:
#                  TSLA  earnings flag  tweet_length  encoded_sentiment  \
# date
# 2021-03-19   1.710022            1.0          19.0                0.0
# 2021-03-19   1.710022            1.0          24.0                0.0
# 2021-03-19   1.710022            1.0         106.0                0.0
# 2021-03-19   1.710022            1.0          63.0                1.0
# 2021-03-22  15.130005            1.0          86.0                0.0
#
#            sentiment  polairty  \
# date
# 2021-03-19   neutral      0.00
# 2021-03-19   neutral      0.00
# 2021-03-19   neutral      0.00
# 2021-03-19  positive      0.28
# 2021-03-22   neutral      0.00
#
#                                                         tweet
# date
# 2021-03-19                                               ð¯
# 2021-03-19
# 2021-03-19  Floor is installed, elevator is operational, w...
# 2021-03-19                   The high bay is measured to fit!
# 2021-03-22  Going well. Lot of work for an extra 20 secs o...

# %%
x_var_list = ['encoded_sentiment']

total_data[x_var_list].head()
# Out:
#             encoded_sentiment
# date
# 2011-12-01                0.0
# 2011-12-01                1.0
# 2011-12-21                1.0
# 2011-12-21               -1.0
# 2011-12-21               -1.0

# %%
y_var_list = ['earnings flag']

total_data[y_var_list].tail()
# Out:
#             earnings flag
# date
# 2021-03-19            1.0
# 2021-03-19            1.0
# 2021-03-19            1.0
# 2021-03-19            1.0
# 2021-03-22            1.0

# %%
total_data[x_var_list] = total_data[x_var_list].shift(1)
total_data[x_var_list].head()
# Out:
#             encoded_sentiment
# date
# 2011-12-01                NaN
# 2011-12-01                0.0
# 2011-12-21                1.0
# 2011-12-21                1.0
# 2011-12-21               -1.0

# %%
elon_signals_df.dropna(subset=x_var_list, inplace=True)
elon_signals_df = elon_signals_df.replace([np.inf, -np.inf], np.nan)
elon_signals_df.tail()
# Out:
#              date  tweet_length  encoded_sentiment sentiment  polarity  \
# 12334  2011-12-03            33                  0   neutral      0.00
# 12335  2011-12-03           136                  1  positive      0.45
# 12336  2011-12-01           118                  0   neutral      0.00
# 12337  2011-12-01           141                  1  positive      0.65
# 12338  2010-06-04            92                  0   neutral      0.00
#
#                                                    tweet
# 12334                  That was a total non sequitur btw
# 12335  Great Voltaire quote, arguably better than Twa...
# 12336  I made the volume on the Model S  http://t.co/...
# 12337  Went to Iceland on Sat to ride bumper cars on ...
# 12338  Please ignore prior tweets, as that was someon...

# %%
X_test=elon_signals_df
X_test=X_test.drop(columns=['sentiment','tweet','polarity'])
X_test.head()
# Out:
#          date  tweet_length  encoded_sentiment
# 0  2021-03-22            86                  0
# 1  2021-03-21            50                  0
# 2  2021-03-21            18                  1
# 3  2021-03-21           128                  1
# 4  2021-03-21           170                  1

# %%
results = tsla_results_df
results.set_index(pd.to_datetime(results['date'], infer_datetime_format=True), inplace=True)
results.drop(columns=['date'], inplace=True)
results.head()
# Out:
#              TSLA  earnings flag
# date
# 2010-06-29    NaN              0
# 2010-06-30 -0.012              0
# 2010-07-01 -0.374              0
# 2010-07-02 -0.552              0
# 2010-07-06 -0.618              0

# %%
model = load('../group1-project2-main/random_forest_model.joblib')
predictions = model.predict(X_test)
predictions
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-34ad4ba0891a> in <module>
# ----> 1 model = load('../group1-project2-main/random_forest_model.joblib')
#       2 predictions = model.predict(X_test)
#       3 predictions
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\joblib\numpy_pickle.py in load(filename, mmap_mode)
#     583                     return load_compatibility(fobj)
#     584
# --> 585                 obj = _unpickle(fobj, filename, mmap_mode)
#     586     return obj
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\joblib\numpy_pickle.py in _unpickle(fobj, filename, mmap_mode)
#     502     obj = None
#     503     try:
# --> 504         obj = unpickler.load()
#     505         if unpickler.compat_mode:
#     506             warnings.warn("The file '%s' has been generated with a "
#
# ~\anaconda3\envs\pyvizenv\lib\pickle.py in load(self)
#    1086                     raise EOFError
#    1087                 assert isinstance(key, bytes_types)
# -> 1088                 dispatch[key[0]](self)
#    1089         except _Stop as stopinst:
#    1090             return stopinst.value
#
# ~\anaconda3\envs\pyvizenv\lib\pickle.py in load_global(self)
#    1374         module = self.readline()[:-1].decode("utf-8")
#    1375         name = self.readline()[:-1].decode("utf-8")
# -> 1376         klass = self.find_class(module, name)
#    1377         self.append(klass)
#    1378     dispatch[GLOBAL[0]] = load_global
#
# ~\anaconda3\envs\pyvizenv\lib\pickle.py in find_class(self, module, name)
#    1424             elif module in _compat_pickle.IMPORT_MAPPING:
#    1425                 module = _compat_pickle.IMPORT_MAPPING[module]
# -> 1426         __import__(module, level=0)
#    1427         if self.proto >= 4:
#    1428             return _getattribute(sys.modules[module], name)[0]
#
# ModuleNotFoundError: No module named 'sklearn.ensemble.forest'

# %%
results["Predicted Value"] = predictions
results

# %%
results['Predicted Value'].replace(0, -1, inplace=True)
results

# %%
(1 + (results['Return'] * results['Predicted Value'])).cumprod().plot()
