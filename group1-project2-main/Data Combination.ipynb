# %%
import pandas as pd
from pathlib import Path
import numpy as np
from datetime import date, timedelta
from matplotlib import pyplot
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\tbder\anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
elon_csv_path = Path('../group1-project2-main/elon_df.csv')
elon_signals_df = pd.read_csv(elon_csv_path)
tsla_csv_path = Path('../group1-project2-main/TSLA_prices_df.csv')
tsla_results_df = pd.read_csv(tsla_csv_path)

# %%
elon_signals_df.head()
# Out:
#          date  tweet_length  encoded_sentiment sentiment  polarity  \
# 0  2021-03-22            86                  0   neutral  0.000000
# 1  2021-03-21            50                  0   neutral  0.000000
# 2  2021-03-21            18                  1  positive  0.350000
# 3  2021-03-21           128                  1  positive  0.400000
# 4  2021-03-21           170                  1  positive  0.286111
#
#                                                tweet
# 0  Going well. Lot of work for an extra 20 secs o...
# 1                  Hopefully will happen this decade
# 2                                               True
# 3  I am accumulating resources to help make life ...
# 4  When vast amounts of manufacturing are needed,...

# %%
elon_signals_df.columns = ['date','tweet_length','encoded_sentiment','sentiment','polairty','tweet']
elon_signals_df.head()
# Out:
#          date  tweet_length  encoded_sentiment sentiment  polairty  \
# 0  2021-03-22            86                  0   neutral  0.000000
# 1  2021-03-21            50                  0   neutral  0.000000
# 2  2021-03-21            18                  1  positive  0.350000
# 3  2021-03-21           128                  1  positive  0.400000
# 4  2021-03-21           170                  1  positive  0.286111
#
#                                                tweet
# 0  Going well. Lot of work for an extra 20 secs o...
# 1                  Hopefully will happen this decade
# 2                                               True
# 3  I am accumulating resources to help make life ...
# 4  When vast amounts of manufacturing are needed,...

# %%
elon_signals_df.set_index('date')
# Out:
#             tweet_length  encoded_sentiment sentiment  polairty  \
# date
# 2021-03-22            86                  0   neutral  0.000000
# 2021-03-21            50                  0   neutral  0.000000
# 2021-03-21            18                  1  positive  0.350000
# 2021-03-21           128                  1  positive  0.400000
# 2021-03-21           170                  1  positive  0.286111
# 2021-03-21            80                  0   neutral  0.000000
# 2021-03-21            25                  0   neutral  0.000000
# 2021-03-21            47                  0   neutral  0.000000
# 2021-03-21            83                  1  positive  0.300000
# 2021-03-21            27                  1  positive  0.400000
# 2021-03-21            55                 -1  negative -0.095833
# 2021-03-21           120                  0   neutral  0.000000
# 2021-03-20            59                  0   neutral  0.000000
# 2021-03-20            46                  1  positive  0.100000
# ...

# %%
tsla_df = tsla_results_df.drop(columns = 'QQQ')

# %%
tsla_df.set_index('date')
# Out:
#                   TSLA  earnings flag
# date
# 2010-06-29         NaN              0
# 2010-06-30   -0.012000              0
# 2010-07-01   -0.374000              0
# 2010-07-02   -0.552000              0
# 2010-07-06   -0.618000              0
# 2010-07-07   -0.062000              0
# 2010-07-08    0.332000              1
# 2010-07-09   -0.012000              0
# 2010-07-12   -0.070000              0
# 2010-07-13    0.218000              1
# 2010-07-14    0.340000              1
# 2010-07-15    0.010000              1
# 2010-07-16    0.150000              1
# 2010-07-19    0.254000              1
# 2010-07-20   -0.322000              0
# 2010-07-21   -0.016000              0
# 2010-07-22    0.156000              1
# 2010-07-23    0.058000              1
# 2010-07-26   -0.068000              0
# 2010-07-27   -0.080000              0
# 2010-07-28    0.034000              1
# 2010-07-29   -0.074000              0
# 2010-07-30   -0.082000              0
# ...

# %%
tsla_df.head()
# Out:
#          date   TSLA  earnings flag
# 0  2010-06-29    NaN              0
# 1  2010-06-30 -0.012              0
# 2  2010-07-01 -0.374              0
# 3  2010-07-02 -0.552              0
# 4  2010-07-06 -0.618              0

# %%
merged_df=tsla_df.merge(elon_signals_df,how='outer')
merged_df.index = pd.to_datetime(merged_df.index)
merged_df.head()
# Out:
#                                      date   TSLA  earnings flag  tweet_length  \
# 1970-01-01 00:00:00.000000000  2010-06-29    NaN            0.0           NaN
# 1970-01-01 00:00:00.000000001  2010-06-30 -0.012            0.0           NaN
# 1970-01-01 00:00:00.000000002  2010-07-01 -0.374            0.0           NaN
# 1970-01-01 00:00:00.000000003  2010-07-02 -0.552            0.0           NaN
# 1970-01-01 00:00:00.000000004  2010-07-06 -0.618            0.0           NaN
#
#                                encoded_sentiment sentiment  polairty tweet
# 1970-01-01 00:00:00.000000000                NaN       NaN       NaN   NaN
# 1970-01-01 00:00:00.000000001                NaN       NaN       NaN   NaN
# 1970-01-01 00:00:00.000000002                NaN       NaN       NaN   NaN
# 1970-01-01 00:00:00.000000003                NaN       NaN       NaN   NaN
# 1970-01-01 00:00:00.000000004                NaN       NaN       NaN   NaN

# %%
merged_df.set_index('date')
# Out:
#              TSLA  earnings flag  tweet_length  encoded_sentiment sentiment  \
# date
# 2010-06-29    NaN            0.0           NaN                NaN       NaN
# 2010-06-30 -0.012            0.0           NaN                NaN       NaN
# 2010-07-01 -0.374            0.0           NaN                NaN       NaN
# 2010-07-02 -0.552            0.0           NaN                NaN       NaN
# 2010-07-06 -0.618            0.0           NaN                NaN       NaN
# 2010-07-07 -0.062            0.0           NaN                NaN       NaN
# 2010-07-08  0.332            1.0           NaN                NaN       NaN
# 2010-07-09 -0.012            0.0           NaN                NaN       NaN
# 2010-07-12 -0.070            0.0           NaN                NaN       NaN
# 2010-07-13  0.218            1.0           NaN                NaN       NaN
# 2010-07-14  0.340            1.0           NaN                NaN       NaN
# ...

# %%
merged_df.tail()
# Out:
#                                      date  TSLA  earnings flag  tweet_length  \
# 1970-01-01 00:00:00.000013644  2011-12-24   NaN            NaN          71.0
# 1970-01-01 00:00:00.000013645  2011-12-04   NaN            NaN          77.0
# 1970-01-01 00:00:00.000013646  2011-12-03   NaN            NaN          33.0
# 1970-01-01 00:00:00.000013647  2011-12-03   NaN            NaN         136.0
# 1970-01-01 00:00:00.000013648  2010-06-04   NaN            NaN          92.0
#
#                                encoded_sentiment sentiment  polairty  \
# 1970-01-01 00:00:00.000013644                0.0   neutral      0.00
# 1970-01-01 00:00:00.000013645                1.0  positive      0.48
# 1970-01-01 00:00:00.000013646                0.0   neutral      0.00
# 1970-01-01 00:00:00.000013647                1.0  positive      0.45
# 1970-01-01 00:00:00.000013648                0.0   neutral      0.00
#
#                                                                            tweet
# ...

# %%
merged_df = merged_df.dropna()

# %%
merged_df.to_csv('total_data.csv')
