# %%
from sklearn.preprocessing import LabelEncoder
from datetime import datetime as dt
from textblob import TextBlob
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('/Users/tbder/group1-project2-main/2021.csv', encoding ='latin1')

pd.set_option('display.max_colwidth', 1000)

df.tail()
# Out:
#        Unnamed: 0                  id     conversation_id    created_at  \
# 12334       12334  142881284019060736  142881284019060736  1.322901e+12
# 12335       12335  142880871391838208  142880871391838208  1.322900e+12
# 12336       12336  142188458125963264  142188458125963264  1.322735e+12
# 12337       12337  142179928203460608  142179928203460608  1.322733e+12
# 12338       12338         15434727182         15434727182  1.275676e+12
#
#                       date  timezone  place  \
# 12334  2011-12-03 08:22:07         0    NaN
# 12335  2011-12-03 08:20:28         0    NaN
# 12336  2011-12-01 10:29:04         0    NaN
# 12337  2011-12-01 09:55:11         0    NaN
# 12338  2010-06-04 18:31:57         0    NaN
#
#                                                                                                                                                tweet  \
# 12334                                                                                                              That was a total non sequitur btw
# 12335       Great Voltaire quote, arguably better than Twain. Hearing news of his own death, Voltaire replied the reports were true, only premature.
# 12336                         I made the volume on the Model S  http://t.co/wMCnT53M go to 11.  Now I just need to work in a miniature Stonehenge...
# 12337  Went to Iceland on Sat to ride bumper cars on ice!  No, not the country, Vlad's rink in Van Nuys. Awesome family fun :)  http://t.co/rBQXJ9IT
# 12338                                                   Please ignore prior tweets, as that was someone pretending to be me :)  This is actually me.
#
#       language hashtags  ... geo  source  user_rt_id user_rt retweet_id  \
# 12334       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12335       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12336       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12337       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12338       en       []  ... NaN     NaN         NaN     NaN        NaN
#
#        reply_to  retweet_date translate trans_src trans_dest
# 12334        []           NaN       NaN       NaN        NaN
# 12335        []           NaN       NaN       NaN        NaN
# 12336        []           NaN       NaN       NaN        NaN
# 12337        []           NaN       NaN       NaN        NaN
# 12338        []           NaN       NaN       NaN        NaN
#
# [5 rows x 39 columns]

# %%
df['date'] = pd.to_datetime(df['date']).dt.normalize()
df
# Out:
#        Unnamed: 0                   id      conversation_id    created_at  \
# 0               0  1373819373090050048  1373669212271566858  1.616379e+12
# 1               1  1373735946244431873  1373669212271566858  1.616359e+12
# 2               2  1373555480870621188  1373328330041229312  1.616316e+12
# 3               3  1373507545315172357  1373263440391864323  1.616305e+12
# 4               4  1373492611231535111  1373357995288051718  1.616301e+12
# 5               5  1373490900807032840  1310591950853201921  1.616301e+12
# 6               6  1373490467807977475  1373451932078022658  1.616301e+12
# 7               7  1373490182117224448  1373485789099753472  1.616301e+12
# 8               8  1373489931574673408  1310591950853201921  1.616300e+12
# 9               9  1373489348960645120  1373485789099753472  1.616300e+12
# 10             10  1373471097559994368  1366405443136856068  1.616296e+12
# 11             11  1373467434380783626  1373436726727745537  1.616295e+12
# 12             12  1373301467440771074  1373297357719232512  1.616256e+12
# 13             13  1373274941202735105  1373065408983527431  1.616249e+12
# 14             14  1373259076465950726  1373084374837694465  1.616245e+12
# 15             15  1373203066556588034  1373203066556588034  1.616232e+12
# 16             16  1373145910549483522  1373051617575010308  1.616218e+12
# 17             17  1373132222555848713  1371142209416929286  1.616215e+12
# 18             18  1373027383511412739  1373025863646740480  1.616190e+12
# 18    2021-03-19         0    NaN
# 19    2021-03-19         0    NaN
# 20    2021-03-19         0    NaN
# 21    2021-03-19         0    NaN
# 22    2021-03-19         0    NaN
# 23    2021-03-19         0    NaN
# 24    2021-03-19         0    NaN
# 25    2021-03-19         0    NaN
# 26    2021-03-19         0    NaN
# 27    2021-03-19         0    NaN
# 28    2021-03-19         0    NaN
# 29    2021-03-18         0    NaN
# ...          ...       ...    ...
# 12309 2011-12-29         0    NaN
# 12310 2011-12-29         0    NaN
# 12311 2011-12-29         0    NaN
# 12312 2011-12-28         0    NaN
# 12313 2011-12-27         0    NaN
# 12314 2011-12-26         0    NaN
# 12315 2011-12-26         0    NaN
# 12316 2011-12-26         0    NaN
# 12317 2011-12-26         0    NaN
# 12318 2011-12-26         0    NaN
# 12319 2011-12-26         0    NaN
# 12320 2011-12-24         0    NaN
# 12321 2011-12-24         0    NaN
# 12322 2011-12-24         0    NaN
# 12323 2011-12-22         0    NaN
# 12324 2011-12-22         0    NaN
# 12325 2011-12-22         0    NaN
# 12326 2011-12-21         0    NaN
# 12327 2011-12-21         0    NaN
# 12328 2011-12-21         0    NaN
# 12329 2011-12-21         0    NaN
# 12330 2011-12-21         0    NaN
# 12331 2011-12-21         0    NaN
# 12332 2011-12-21         0    NaN
# 12333 2011-12-04         0    NaN
# 12334 2011-12-03         0    NaN
# 12335 2011-12-03         0    NaN
# 12336 2011-12-01         0    NaN
# 12337 2011-12-01         0    NaN
# 12338 2010-06-04         0    NaN
#
#                                                                                                                                                                                                   tweet  \
# 0                                                                                                                @bluemoondance74 @NASASpaceflight Going well. Lot of work for an extra 20 secs of Isp!
# 1                                                                                                                                                    @NASASpaceflight Hopefully will happen this decade
# 2                                                                                                                                                                                    @newscientist True
# 3                                                                      @cleantechnica I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars
# 4                            @CathieDWood When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.
# 5                                                                                                                      @Swaggerheim @SciGuySpace Not trying to roast, just being as literal as possible
# 6                                                                                                                                                                             @johnkrausphotos ð¤£ð¤£
# 7                                                                                                                                                       @AtomicsAstro @PPathole Yeah, but Iâm English
# 8                                                                                                                   @SciGuySpace Not quite how I would tell the story, but itâs probably worth a read
# 9                                                                                                                                                                           @PPathole This is important
# 10                                                                                                                                              @TrungTPhan Wow, hard to believe that was 17 years ago!
# 11                                                                             @TeslaPhx @CodingMark @EvaFoxU @jrosinski97 @daelmor @piangfa @Kristennetten @jessica_kirsh @JC_finance @jeremyjudkins !
# 12                                                                                                                                          @Erdayastronaut @Twitter @TwitterComms @verified @jack Sigh
# 13                                                                                                                                                       @OwenSparks_ I actually ate the sandwich haha!
# 14                                                                                                                                                                              @TheBabylonBee ð¤£ð¤£
# 15                                                                                                                                                       Music in zero gravity  https://t.co/bepfMipjrE
# 16     @WholeMarsBlog Given significant architectural changes, including fundamental improvements to pure vision, there is limited value to testing 8.x. Hoping to upload V9.0 &amp; button next month.
# 17                                                                                             @SpacexVision An orbital propellant depot optimized for cryogenic storage probably makes sense long-term
# 18                                                                                                                                            @Teslarati ÐÑÐµÑÑÑÐ¿Ð»ÐµÐ½ÑÐµ Ð¸ Ð½Ð°ÐºÐ°Ð·Ð°Ð½ÑÐµ
# 12330                                                                  Why does the crowd cry over the glorious leader Kim Il Sung's death?  Fear of being shot may play a role:   http://t.co/hoQrYtG1
# 12331                                                                                    Sam Harris also wrote a nice piece on the awesomeness of Hitchens:  http://t.co/fPkLiK3v May the good man RIP.
# 12332                                                                                     Read "Lying", the new book by my friend Sam Harris.  Excellent cover art and lots of good reasons not to lie!
# 12333                                                                                                                     Am reading a great biography of Ben Franklin by Isaacson. Highly recommended.
# 12334                                                                                                                                                                 That was a total non sequitur btw
# 12335                                                          Great Voltaire quote, arguably better than Twain. Hearing news of his own death, Voltaire replied the reports were true, only premature.
# 12336                                                                            I made the volume on the Model S  http://t.co/wMCnT53M go to 11.  Now I just need to work in a miniature Stonehenge...
# 12337                                                     Went to Iceland on Sat to ride bumper cars on ice!  No, not the country, Vlad's rink in Van Nuys. Awesome family fun :)  http://t.co/rBQXJ9IT
# 12338                                                                                                      Please ignore prior tweets, as that was someone pretending to be me :)  This is actually me.
#
#       language hashtags  ... geo  source  user_rt_id user_rt retweet_id  \
# 0           en       []  ... NaN     NaN         NaN     NaN        NaN
# 1           en       []  ... NaN     NaN         NaN     NaN        NaN
# 2           en       []  ... NaN     NaN         NaN     NaN        NaN
# 3           en       []  ... NaN     NaN         NaN     NaN        NaN
# 4           en       []  ... NaN     NaN         NaN     NaN        NaN
# 5           en       []  ... NaN     NaN         NaN     NaN        NaN
# 6          und       []  ... NaN     NaN         NaN     NaN        NaN
# 7           en       []  ... NaN     NaN         NaN     NaN        NaN
# 8           en       []  ... NaN     NaN         NaN     NaN        NaN
# 9           en       []  ... NaN     NaN         NaN     NaN        NaN
# 10          en       []  ... NaN     NaN         NaN     NaN        NaN
# 11         und       []  ... NaN     NaN         NaN     NaN        NaN
# 12          en       []  ... NaN     NaN         NaN     NaN        NaN
# 13          en       []  ... NaN     NaN         NaN     NaN        NaN
# 14         und       []  ... NaN     NaN         NaN     NaN        NaN
# 15          en       []  ... NaN     NaN         NaN     NaN        NaN
# 16          en       []  ... NaN     NaN         NaN     NaN        NaN
# 17          en       []  ... NaN     NaN         NaN     NaN        NaN
# 18          uk       []  ... NaN     NaN         NaN     NaN        NaN
# 19          en       []  ... NaN     NaN         NaN     NaN        NaN
# 20          en       []  ... NaN     NaN         NaN     NaN        NaN
# 21          en       []  ... NaN     NaN         NaN     NaN        NaN
# 22         und       []  ... NaN     NaN         NaN     NaN        NaN
# 23          en       []  ... NaN     NaN         NaN     NaN        NaN
# 24          en       []  ... NaN     NaN         NaN     NaN        NaN
# 25         und       []  ... NaN     NaN         NaN     NaN        NaN
# 26         und       []  ... NaN     NaN         NaN     NaN        NaN
# 27          en       []  ... NaN     NaN         NaN     NaN        NaN
# 28          en       []  ... NaN     NaN         NaN     NaN        NaN
# 29          en       []  ... NaN     NaN         NaN     NaN        NaN
# ...        ...      ...  ...  ..     ...         ...     ...        ...
# 12309       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12310       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12311       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12312       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12313       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12314       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12315       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12316       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12317       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12318       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12319      und       []  ... NaN     NaN         NaN     NaN        NaN
# 12320       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12321       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12322       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12323       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12324       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12325       en       []  ... NaN     NaN         NaN     NaN        NaN
# 12326       en       []  ... NaN     NaN         NaN     NaN        NaN
# 
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'screen_name': 'Teslarati', 'name': 'TESLARATI', 'id': '1308211178'}]
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [{'screen_name': 'MarcusHouse', 'name': 'Marcus House', 'id': '718325771392172033'}]
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [{'screen_name': 'RationalEtienne', 'name': 'TechnoPope of Muskanity ð', 'id': '2241150253'}, {'screen_name': 'jordanbpeterson', 'name': 'Dr Jordan B Peterson', 'id': '95092020'}]
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [{'screen_name': 'VinterNix', 'name': 'VinterNix', 'id': '1075124697669480453'}, {'screen_name': 'Bell', 'name': 'Bell', 'id': '38807340'}]
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [{'screen_name': 'MoMoButFaster', 'name': 'ð xX_P@W_L0V3R_Xxð ', 'id': '3233011012'}]
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'screen_name': 'remouherek', 'name': 'Remo Uherek', 'id': '3549601'}, {'screen_name': 'SciGuySpace', 'name': 'Eric Berger', 'id': '15726728'}]
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [{'screen_name': 'jordanbpeterson', 'name': 'Dr Jordan B Peterson', 'id': '95092020'}]
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [{'screen_name': 'teslaownersSV', 'name': 'Tesla Owners Of Silicon Valley', 'id': '1016059981907386368'}]
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                []
# ...
# 12324                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             []
# 12325                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             []
# 12326                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             []
# 12327                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             []
# 12328                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             []
# 12329                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             []
# 12330                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             []
# 12331                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             []
# 12332                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             []
# 12333                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             []
# 12334                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             []
# 12335                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             []
# 12336                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             []
# 12337                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             []
# 12338                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             []
#
#        retweet_date translate trans_src trans_dest
# 0               NaN       NaN       NaN        NaN
# 1               NaN       NaN       NaN        NaN
# 2               NaN       NaN       NaN        NaN
# 3               NaN       NaN       NaN        NaN
# 4               NaN       NaN       NaN        NaN
# 5               NaN       NaN       NaN        NaN
# 6               NaN       NaN       NaN        NaN
# 7               NaN       NaN       NaN        NaN
# 8               NaN       NaN       NaN        NaN
# 9               NaN       NaN       NaN        NaN
# 10              NaN       NaN       NaN        NaN
# 11              NaN       NaN       NaN        NaN
# 12              NaN       NaN       NaN        NaN
# 13              NaN       NaN       NaN        NaN
# 14              NaN       NaN       NaN        NaN
# 15              NaN       NaN       NaN        NaN
# 16              NaN       NaN       NaN        NaN
# 17              NaN       NaN       NaN        NaN
# 18              NaN       NaN       NaN        NaN
# 19              NaN       NaN       NaN        NaN
# 20              NaN       NaN       NaN        NaN
# 21              NaN       NaN       NaN        NaN
# 22              NaN       NaN       NaN        NaN
# 23              NaN       NaN       NaN        NaN
# 24              NaN       NaN       NaN        NaN
# 25              NaN       NaN       NaN        NaN
# 26              NaN       NaN       NaN        NaN
# 27              NaN       NaN       NaN        NaN
# 28              NaN       NaN       NaN        NaN
# 29              NaN       NaN       NaN        NaN
# ...             ...       ...       ...        ...
# 12309           NaN       NaN       NaN        NaN
# 12310           NaN       NaN       NaN        NaN
# 12311           NaN       NaN       NaN        NaN
# 12312           NaN       NaN       NaN        NaN
# 12313           NaN       NaN       NaN        NaN
# 12314           NaN       NaN       NaN        NaN
# 12315           NaN       NaN       NaN        NaN
# 12316           NaN       NaN       NaN        NaN
# 12317           NaN       NaN       NaN        NaN
# 12318           NaN       NaN       NaN        NaN
# 12319           NaN       NaN       NaN        NaN
# 12320           NaN       NaN       NaN        NaN
# 12321           NaN       NaN       NaN        NaN
# 12322           NaN       NaN       NaN        NaN
# 12323           NaN       NaN       NaN        NaN
# 12324           NaN       NaN       NaN        NaN
# 12325           NaN       NaN       NaN        NaN
# 12326           NaN       NaN       NaN        NaN
# 12327           NaN       NaN       NaN        NaN
# 12328           NaN       NaN       NaN        NaN
# 12329           NaN       NaN       NaN        NaN
# 12330           NaN       NaN       NaN        NaN
# 12331           NaN       NaN       NaN        NaN
# 12332           NaN       NaN       NaN        NaN
# 12333           NaN       NaN       NaN        NaN
# 12334           NaN       NaN       NaN        NaN
# 12335           NaN       NaN       NaN        NaN
# 12336           NaN       NaN       NaN        NaN
# 12337           NaN       NaN       NaN        NaN
# 12338           NaN       NaN       NaN        NaN
#
# [12339 rows x 39 columns]

# %%
df.tweet = df.tweet.astype(str)


tweet_lens = []
for tweet in df.tweet:
    tweet_lens.append(len(tweet))
    
df_tweet_len = pd.DataFrame(tweet_lens)


df_tweet_len.columns = ['tweet_length']

df_tweet_len.head()
# Out:
#    tweet_length
# 0            86
# 1            50
# 2            18
# 3           128
# 4           170

# %%
df1 = pd.concat([df, df_tweet_len], axis=1)

df1.head()
# Out:
#    Unnamed: 0                   id      conversation_id    created_at  \
# 0           0  1373819373090050048  1373669212271566858  1.616379e+12
# 1           1  1373735946244431873  1373669212271566858  1.616359e+12
# 2           2  1373555480870621188  1373328330041229312  1.616316e+12
# 3           3  1373507545315172357  1373263440391864323  1.616305e+12
# 4           4  1373492611231535111  1373357995288051718  1.616301e+12
#
#         date  timezone  place  \
# 0 2021-03-22         0    NaN
# 1 2021-03-21         0    NaN
# 2 2021-03-21         0    NaN
# 3 2021-03-21         0    NaN
# 4 2021-03-21         0    NaN
#
#                                                                                                                                                                         tweet  \
# 0                                                                                      @bluemoondance74 @NASASpaceflight Going well. Lot of work for an extra 20 secs of Isp!
# 1                                                                                                                          @NASASpaceflight Hopefully will happen this decade
# 2                                                                                                                                                          @newscientist True
# 3                                            @cleantechnica I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars
# 4  @CathieDWood When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.
#
#   language hashtags  ... source  user_rt_id  user_rt retweet_id  \
# 0       en       []  ...    NaN         NaN      NaN        NaN
# 1       en       []  ...    NaN         NaN      NaN        NaN
# 2       en       []  ...    NaN         NaN      NaN        NaN
# 3       en       []  ...    NaN         NaN      NaN        NaN
# 4       en       []  ...    NaN         NaN      NaN        NaN
#
#                                                                                                                                                             reply_to  \
# 0  [{'screen_name': 'bluemoondance74', 'name': 'Reagan', 'id': '844015154643648512'}, {'screen_name': 'NASASpaceflight', 'name': 'Chris B - NSF', 'id': '21292523'}]
# 1                                                                                    [{'screen_name': 'NASASpaceflight', 'name': 'Chris B - NSF', 'id': '21292523'}]
# 2                                                                                       [{'screen_name': 'newscientist', 'name': 'New Scientist', 'id': '19658826'}]
# 3                                                                                      [{'screen_name': 'cleantechnica', 'name': 'CleanTechnica', 'id': '17060015'}]
# 4                                                                                        [{'screen_name': 'CathieDWood', 'name': 'Cathie Wood', 'id': '2361631088'}]
#
#    retweet_date  translate trans_src trans_dest tweet_length
# 0           NaN        NaN       NaN        NaN           86
# 1           NaN        NaN       NaN        NaN           50
# 2           NaN        NaN       NaN        NaN           18
# 3           NaN        NaN       NaN        NaN          128
# 4           NaN        NaN       NaN        NaN          170
#
# [5 rows x 40 columns]

# %%
df = df1
df.drop(columns=['id'], inplace=True)
df.head()
# Out:
#    Unnamed: 0      conversation_id    created_at       date  timezone  place  \
# 0           0  1373669212271566858  1.616379e+12 2021-03-22         0    NaN
# 1           1  1373669212271566858  1.616359e+12 2021-03-21         0    NaN
# 2           2  1373328330041229312  1.616316e+12 2021-03-21         0    NaN
# 3           3  1373263440391864323  1.616305e+12 2021-03-21         0    NaN
# 4           4  1373357995288051718  1.616301e+12 2021-03-21         0    NaN
#
#                                                                                                                                                                         tweet  \
# 0                                                                                      @bluemoondance74 @NASASpaceflight Going well. Lot of work for an extra 20 secs of Isp!
# 1                                                                                                                          @NASASpaceflight Hopefully will happen this decade
# 2                                                                                                                                                          @newscientist True
# 3                                            @cleantechnica I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars
# 4  @CathieDWood When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.
#
#   language hashtags cashtags  ...  source  user_rt_id user_rt retweet_id  \
# 0       en       []       []  ...     NaN         NaN     NaN        NaN
# 1       en       []       []  ...     NaN         NaN     NaN        NaN
# 2       en       []       []  ...     NaN         NaN     NaN        NaN
# 3       en       []       []  ...     NaN         NaN     NaN        NaN
# 4       en       []       []  ...     NaN         NaN     NaN        NaN
#
#                                                                                                                                                             reply_to  \
# 0  [{'screen_name': 'bluemoondance74', 'name': 'Reagan', 'id': '844015154643648512'}, {'screen_name': 'NASASpaceflight', 'name': 'Chris B - NSF', 'id': '21292523'}]
# 1                                                                                    [{'screen_name': 'NASASpaceflight', 'name': 'Chris B - NSF', 'id': '21292523'}]
# 2                                                                                       [{'screen_name': 'newscientist', 'name': 'New Scientist', 'id': '19658826'}]
# 3                                                                                      [{'screen_name': 'cleantechnica', 'name': 'CleanTechnica', 'id': '17060015'}]
# 4                                                                                        [{'screen_name': 'CathieDWood', 'name': 'Cathie Wood', 'id': '2361631088'}]
#
#    retweet_date translate trans_src trans_dest  tweet_length
# 0           NaN       NaN       NaN        NaN            86
# 1           NaN       NaN       NaN        NaN            50
# 2           NaN       NaN       NaN        NaN            18
# 3           NaN       NaN       NaN        NaN           128
# 4           NaN       NaN       NaN        NaN           170
#
# [5 rows x 39 columns]

# %%
df = df[['date', 'tweet', 'tweet_length']]

df.head()
# Out:
#         date  \
# 0 2021-03-22
# 1 2021-03-21
# 2 2021-03-21
# 3 2021-03-21
# 4 2021-03-21
#
#                                                                                                                                                                         tweet  \
# 0                                                                                      @bluemoondance74 @NASASpaceflight Going well. Lot of work for an extra 20 secs of Isp!
# 1                                                                                                                          @NASASpaceflight Hopefully will happen this decade
# 2                                                                                                                                                          @newscientist True
# 3                                            @cleantechnica I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars
# 4  @CathieDWood When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.
#
#    tweet_length
# 0            86
# 1            50
# 2            18
# 3           128
# 4           170

# %%
df.date.dtypes


df['date'] = pd.to_datetime(df['date'])

df.head()
# Out:
# C:\Users\tbder\anaconda3\envs\pyvizenv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#         date  \
# 0 2021-03-22
# 1 2021-03-21
# 2 2021-03-21
# 3 2021-03-21
# 4 2021-03-21
#
#                                                                                                                                                                         tweet  \
# 0                                                                                      @bluemoondance74 @NASASpaceflight Going well. Lot of work for an extra 20 secs of Isp!
# 1                                                                                                                          @NASASpaceflight Hopefully will happen this decade
# 2                                                                                                                                                          @newscientist True
# 3                                            @cleantechnica I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars
# 4  @CathieDWood When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.
#
#    tweet_length
# 0            86
# 1            50
# 2            18
# 3           128
# 4           170

# %%
df.set_index('date', inplace = True)

df.head()
# Out:
#                                                                                                                                                                                  tweet  \
# date
# 2021-03-22                                                                                      @bluemoondance74 @NASASpaceflight Going well. Lot of work for an extra 20 secs of Isp!
# 2021-03-21                                                                                                                          @NASASpaceflight Hopefully will happen this decade
# 2021-03-21                                                                                                                                                          @newscientist True
# 2021-03-21                                            @cleantechnica I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars
# 2021-03-21  @CathieDWood When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.
#
#             tweet_length
# date
# 2021-03-22            86
# 2021-03-21            50
# 2021-03-21            18
# 2021-03-21           128
# 2021-03-21           170

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12339 entries, 2021-03-22 to 2010-06-04
# Data columns (total 2 columns):
# tweet           12339 non-null object
# tweet_length    12339 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 289.2+ KB

# %%
xxx = df.tweet[0]
xxx
# Out:
# '@bluemoondance74 @NASASpaceflight Going well. Lot of work for an extra 20 secs of Isp!'

# %%
tweet_list = df.tweet.tolist()
tweet_list[0]
# Out:
# '@bluemoondance74 @NASASpaceflight Going well. Lot of work for an extra 20 secs of Isp!'

# %%
def clean_tweet_http(dirty_string):
    sep = "https://" 
    if sep in dirty_string:
        clean = dirty_string.split(sep, 1)[0]
    else:
        clean = dirty_string
    return clean

# %%
clean_tweets1 = []

for i in range(0, len(tweet_list)):
    x = clean_tweet_http(tweet_list[i])
    clean_tweets1.append(x)

# %%
clean_tweets1[:10]
# Out:
# ['@bluemoondance74 @NASASpaceflight Going well. Lot of work for an extra 20 secs of Isp!',
#  '@NASASpaceflight Hopefully will happen this decade',
#  '@newscientist True',
#  '@cleantechnica I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars',
#  '@CathieDWood When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.',
#  '@Swaggerheim @SciGuySpace Not trying to roast, just being as literal as possible',
#  '@johnkrausphotos ð\x9f¤£ð\x9f¤£',
#  '@AtomicsAstro @PPathole Yeah, but Iâ\x80\x99m English',
#  '@SciGuySpace Not quite how I would tell the story, but itâ\x80\x99s probably worth a read',
#  '@PPathole This is important']

# %%
# def clean_tweet_usernames(dirty_string):
#     sep = "https://" 
#     if sep in dirty_string:
#         clean = dirty_string.split(sep, 1)[0]
#     else:
#         clean = dirty_string
#     return clean

# %%
clean_tweets2 = []

# for i in range(0, len(clean_tweets1)):
for tweet in clean_tweets1:
    result = re.sub('@([A-Za-z0-9_]+) ', '', tweet)
    clean_tweets2.append(result)

# %%
clean_tweets2[:10]
# Out:
# ['Going well. Lot of work for an extra 20 secs of Isp!',
#  'Hopefully will happen this decade',
#  'True',
#  'I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars',
#  'When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.',
#  'Not trying to roast, just being as literal as possible',
#  'ð\x9f¤£ð\x9f¤£',
#  'Yeah, but Iâ\x80\x99m English',
#  'Not quite how I would tell the story, but itâ\x80\x99s probably worth a read',
#  'This is important']

# %%
clean_tweets3 = []

# for i in range(0, len(clean_tweets1)):
for tweet in clean_tweets2:
    result = re.sub('RT @([A-Za-z0-9_]+\:) ', '', tweet)
    clean_tweets3.append(result)
    
clean_tweets3[:10]
# Out:
# ['Going well. Lot of work for an extra 20 secs of Isp!',
#  'Hopefully will happen this decade',
#  'True',
#  'I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars',
#  'When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.',
#  'Not trying to roast, just being as literal as possible',
#  'ð\x9f¤£ð\x9f¤£',
#  'Yeah, but Iâ\x80\x99m English',
#  'Not quite how I would tell the story, but itâ\x80\x99s probably worth a read',
#  'This is important']

# %%
clean_tweets4 = []

for tweet in clean_tweets3:
    result = re.sub('\n', ' ', tweet)
    clean_tweets4.append(result)

    
clean_tweets4[:10]
# Out:
# ['Going well. Lot of work for an extra 20 secs of Isp!',
#  'Hopefully will happen this decade',
#  'True',
#  'I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars',
#  'When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.',
#  'Not trying to roast, just being as literal as possible',
#  'ð\x9f¤£ð\x9f¤£',
#  'Yeah, but Iâ\x80\x99m English',
#  'Not quite how I would tell the story, but itâ\x80\x99s probably worth a read',
#  'This is important']

# %%
clean_tweets5 = []

for tweet in clean_tweets4:
    result = re.sub(' https:?', '', tweet)
    clean_tweets5.append(result)
    
clean_tweets5[:10]
# Out:
# ['Going well. Lot of work for an extra 20 secs of Isp!',
#  'Hopefully will happen this decade',
#  'True',
#  'I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars',
#  'When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.',
#  'Not trying to roast, just being as literal as possible',
#  'ð\x9f¤£ð\x9f¤£',
#  'Yeah, but Iâ\x80\x99m English',
#  'Not quite how I would tell the story, but itâ\x80\x99s probably worth a read',
#  'This is important']

# %%
clean_tweets6 = []

for tweet in clean_tweets5:
    result = re.sub('@([A-Za-z0-9_]+)', '', tweet)
    clean_tweets6.append(result)

# %%
clean_tweets7 = []

for tweet in clean_tweets6:
    result = re.sub('\s([#][\w_-]+)', '', tweet)
    clean_tweets7.append(result)

# %%
clean_tweets8 = []

for tweet in clean_tweets7:
    result = re.sub('([#][\w_-]+)', '', tweet)
    clean_tweets8.append(result)

# %%
clean_tweets8[:10]
# Out:
# ['Going well. Lot of work for an extra 20 secs of Isp!',
#  'Hopefully will happen this decade',
#  'True',
#  'I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars',
#  'When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.',
#  'Not trying to roast, just being as literal as possible',
#  'ð\x9f¤£ð\x9f¤£',
#  'Yeah, but Iâ\x80\x99m English',
#  'Not quite how I would tell the story, but itâ\x80\x99s probably worth a read',
#  'This is important']

# %%
def clean_tweet(tweet):
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

# %%
result
# Out:
# 'Please ignore prior tweets, as that was someone pretending to be me :)  This is actually me.'

# %%
x1 = clean_tweet(result.lower())

# %%
def get_tweet_sentiment(tweet):
    
    analysis = TextBlob(clean_tweet(tweet.lower())) 
        # set sentiment 
    if analysis.sentiment.polarity > 0: 
        return 'positive', analysis.sentiment.polarity
    elif analysis.sentiment.polarity == 0: 
        return 'neutral', analysis.sentiment.polarity
    else: 
        return 'negative', analysis.sentiment.polarity
    
get_tweet_sentiment(result)
# Out:
# ('neutral', 0.0)

# %%
listy = []
for t in clean_tweets8:
    listy.append(get_tweet_sentiment(t))
    
len(listy)
# Out:
# 12339

# %%
sentiments_list = []
polarities_list = []


for tweet in listy:
    sentiments_list.append(tweet[0])
    polarities_list.append(tweet[1])

# %%
sentiments = pd.DataFrame(sentiments_list)
polarities = pd.DataFrame(polarities_list)

len(df)
# Out:
# 12339

# %%
len(sentiments)
# Out:
# 12339

# %%
df2 = df

# %%
sentiments.index = df.index

# %%
polarities.index = df.index

# %%
df = pd.concat([df2, sentiments, polarities], axis=1)

# %%
df.head()
# Out:
#                                                                                                                                                                                  tweet  \
# date
# 2021-03-22                                                                                      @bluemoondance74 @NASASpaceflight Going well. Lot of work for an extra 20 secs of Isp!
# 2021-03-21                                                                                                                          @NASASpaceflight Hopefully will happen this decade
# 2021-03-21                                                                                                                                                          @newscientist True
# 2021-03-21                                            @cleantechnica I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars
# 2021-03-21  @CathieDWood When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.
#
#             tweet_length         0         0
# date
# 2021-03-22            86   neutral  0.000000
# 2021-03-21            50   neutral  0.000000
# 2021-03-21            18  positive  0.350000
# 2021-03-21           128  positive  0.400000
# 2021-03-21           170  positive  0.286111

# %%
df.columns = ['tweet', 'tweet_length', 'sentiment', 'polarity']

# %%
ct_series = pd.Series(clean_tweets8)
ct_series.index = df.index

ct_series[0]
# Out:
# 'Going well. Lot of work for an extra 20 secs of Isp!'

# %%
ct_series.index
# Out:
# DatetimeIndex(['2021-03-22', '2021-03-21', '2021-03-21', '2021-03-21',
#                '2021-03-21', '2021-03-21', '2021-03-21', '2021-03-21',
#                '2021-03-21', '2021-03-21',
#                ...
#                '2011-12-21', '2011-12-21', '2011-12-21', '2011-12-21',
#                '2011-12-04', '2011-12-03', '2011-12-03', '2011-12-01',
#                '2011-12-01', '2010-06-04'],
#               dtype='datetime64[ns]', name='date', length=12339, freq=None)

# %%
elon_df = pd.concat([df, ct_series], axis=1)
elon_df = elon_df.drop(columns=['tweet'])
elon_df.columns = ['tweet_length', 'sentiment', 'polarity', 'tweet']
elon_df.head()
# Out:
#             tweet_length sentiment  polarity  \
# date
# 2021-03-22            86   neutral  0.000000
# 2021-03-21            50   neutral  0.000000
# 2021-03-21            18  positive  0.350000
# 2021-03-21           128  positive  0.400000
# 2021-03-21           170  positive  0.286111
#
#                                                                                                                                                                     tweet
# date
# 2021-03-22                                                                                                           Going well. Lot of work for an extra 20 secs of Isp!
# 2021-03-21                                                                                                                              Hopefully will happen this decade
# 2021-03-21                                                                                                                                                           True
# 2021-03-21                                              I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars
# 2021-03-21  When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.

# %%
le = LabelEncoder()
sen = elon_df.sentiment
sen = le.fit_transform(sen)
sen = pd.Series(sen-1)
sen.index = elon_df.index
elon_df = pd.concat([elon_df, sen], axis=1)
elon_df.columns = ['tweet_length','sentiment', 'polarity', 'tweet', 'encoded_sentiment',]


elon_df.head()
# Out:
#             tweet_length sentiment  polarity  \
# date
# 2021-03-22            86   neutral  0.000000
# 2021-03-21            50   neutral  0.000000
# 2021-03-21            18  positive  0.350000
# 2021-03-21           128  positive  0.400000
# 2021-03-21           170  positive  0.286111
#
#                                                                                                                                                                     tweet  \
# date
# 2021-03-22                                                                                                           Going well. Lot of work for an extra 20 secs of Isp!
# 2021-03-21                                                                                                                              Hopefully will happen this decade
# 2021-03-21                                                                                                                                                           True
# 2021-03-21                                              I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars
# 2021-03-21  When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.
#
#             encoded_sentiment
# date
# 2021-03-22                  0
# 2021-03-21                  0
# 2021-03-21                  1
# 2021-03-21                  1
# 2021-03-21                  1

# %%
elon_df = elon_df[['tweet_length', 'encoded_sentiment', 'sentiment', 'polarity', 'tweet']]
elon_df.describe()
# Out:
#        tweet_length  encoded_sentiment      polarity
# count  12339.000000       12339.000000  12339.000000
# mean      90.777454           0.328957      0.119987
# std       66.422119           0.699777      0.258747
# min        1.000000          -1.000000     -1.000000
# 25%       39.000000           0.000000      0.000000
# 50%       74.000000           0.000000      0.000000
# 75%      124.000000           1.000000      0.250000
# max      430.000000           1.000000      1.000000

# %%
elon_df.tail()
# Out:
#             tweet_length  encoded_sentiment sentiment  polarity  \
# date
# 2011-12-03            33                  0   neutral      0.00
# 2011-12-03           136                  1  positive      0.45
# 2011-12-01           118                  0   neutral      0.00
# 2011-12-01           141                  1  positive      0.65
# 2010-06-04            92                  0   neutral      0.00
#
#                                                                                                                                                     tweet
# date
# 2011-12-03                                                                                                              That was a total non sequitur btw
# 2011-12-03       Great Voltaire quote, arguably better than Twain. Hearing news of his own death, Voltaire replied the reports were true, only premature.
# 2011-12-01                         I made the volume on the Model S  http://t.co/wMCnT53M go to 11.  Now I just need to work in a miniature Stonehenge...
# 2011-12-01  Went to Iceland on Sat to ride bumper cars on ice!  No, not the country, Vlad's rink in Van Nuys. Awesome family fun :)  http://t.co/rBQXJ9IT
# 2010-06-04                                                   Please ignore prior tweets, as that was someone pretending to be me :)  This is actually me.

# %%
elon_df_clean = elon_df[['encoded_sentiment']]

# %%
elon_df_clean.tail()
# Out:
#             encoded_sentiment
# date
# 2011-12-03                  0
# 2011-12-03                  1
# 2011-12-01                  0
# 2011-12-01                  1
# 2010-06-04                  0

# %%
elon_df.to_csv('elon_df.csv')

# %%
pd.to_datetime(df.index)
# Out:
# DatetimeIndex(['2021-03-22', '2021-03-21', '2021-03-21', '2021-03-21',
#                '2021-03-21', '2021-03-21', '2021-03-21', '2021-03-21',
#                '2021-03-21', '2021-03-21',
#                ...
#                '2011-12-21', '2011-12-21', '2011-12-21', '2011-12-21',
#                '2011-12-04', '2011-12-03', '2011-12-03', '2011-12-01',
#                '2011-12-01', '2010-06-04'],
#               dtype='datetime64[ns]', name='date', length=12339, freq=None)

# %%
elon_df.head()
# Out:
#             tweet_length  encoded_sentiment sentiment  polarity  \
# date
# 2021-03-22            86                  0   neutral  0.000000
# 2021-03-21            50                  0   neutral  0.000000
# 2021-03-21            18                  1  positive  0.350000
# 2021-03-21           128                  1  positive  0.400000
# 2021-03-21           170                  1  positive  0.286111
#
#                                                                                                                                                                     tweet
# date
# 2021-03-22                                                                                                           Going well. Lot of work for an extra 20 secs of Isp!
# 2021-03-21                                                                                                                              Hopefully will happen this decade
# 2021-03-21                                                                                                                                                           True
# 2021-03-21                                              I am accumulating resources to help make life multiplanetary &amp; extend the light of consciousness to the stars
# 2021-03-21  When vast amounts of manufacturing are needed, as in robotaxis, this slows down rate of introduction, so maybe more like winner-takes-a-quarter. Still great.
